# %%
# !pip install sortedcontainers
# !pip install fastplotlib
# !pip install PySide6
# !pip install wgpu
# !pip install cmasher
# Out:
# Requirement already satisfied: fastplotlib in c:\users\1\appdata\roaming\python\python310\site-packages (0.1.0a8)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from fastplotlib) (1.1.1)
# Requirement already satisfied: jupyter-rfb in c:\users\1\appdata\roaming\python\python310\site-packages (from fastplotlib) (0.3.2)
# Requirement already satisfied: numpy in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from fastplotlib) (1.23.4)
# Requirement already satisfied: jupyterlab in c:\users\1\appdata\roaming\python\python310\site-packages (from fastplotlib) (3.6.1)
# Requirement already satisfied: pygfx>=0.1.10 in c:\users\1\appdata\roaming\python\python310\site-packages (from fastplotlib) (0.1.10)
# Requirement already satisfied: ipywidgets<8.0.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from fastplotlib) (7.7.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipywidgets<8.0.0->fastplotlib) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipywidgets<8.0.0->fastplotlib) (6.17.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0.0->fastplotlib) (3.6.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipywidgets<8.0.0->fastplotlib) (8.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipywidgets<8.0.0->fastplotlib) (5.5.0)
# Requirement already satisfied: freetype-py in c:\users\1\appdata\roaming\python\python310\site-packages (from pygfx>=0.1.10->fastplotlib) (2.3.0)
# Requirement already satisfied: uharfbuzz in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from pygfx>=0.1.10->fastplotlib) (0.33.0)
# Requirement already satisfied: wgpu<0.9.0,>=0.8.4 in c:\users\1\appdata\roaming\python\python310\site-packages (from pygfx>=0.1.10->fastplotlib) (0.8.4)
# Requirement already satisfied: Jinja2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from pygfx>=0.1.10->fastplotlib) (3.1.2)
# Requirement already satisfied: nbclassic in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (0.4.8)
# Requirement already satisfied: tomli in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (2.0.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyterlab->fastplotlib) (2.19.0)
# Requirement already satisfied: jupyter-server-ydoc<0.7.0,>=0.6.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyterlab->fastplotlib) (0.6.1)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (1.21.0)
# Requirement already satisfied: packaging in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (21.3)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (6.2)
# Requirement already satisfied: jupyter-ydoc~=0.2.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (0.2.2)
# Requirement already satisfied: jupyter-core in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (4.11.2)
# Requirement already satisfied: notebook<7 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab->fastplotlib) (6.5.2)
# Requirement already satisfied: nest-asyncio in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (7.4.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (0.1.6)
# Requirement already satisfied: psutil in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (5.9.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (24.0.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (3.0.32)
# Requirement already satisfied: backcall in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (2.13.0)
# Requirement already satisfied: colorama in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.6.0)
# Requirement already satisfied: pickleshare in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.7.5)
# Requirement already satisfied: decorator in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from Jinja2->pygfx>=0.1.10->fastplotlib) (2.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (3.6.2)
# Requirement already satisfied: prometheus-client in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.15.0)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (5.7.0)
# Requirement already satisfied: Send2Trash in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.17.0)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (7.2.3)
# Requirement already satisfied: websocket-client in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (1.4.2)
# Requirement already satisfied: argon2-cffi in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (21.3.0)
# Requirement already satisfied: pywinpty in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (2.0.9)
# Requirement already satisfied: pywin32>=1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-core->jupyterlab->fastplotlib) (304)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (0.8.2)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (0.6.0)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-ydoc~=0.2.2->jupyterlab->fastplotlib) (0.5.5)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab->fastplotlib) (4.17.3)
# Requirement already satisfied: requests>=2.28 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2.28.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab->fastplotlib) (0.9.11)
# Requirement already satisfied: babel>=2.10 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2.11.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbclassic->jupyterlab->fastplotlib) (0.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from packaging->jupyterlab->fastplotlib) (3.0.9)
# Requirement already satisfied: cffi>=1.15.0rc2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from wgpu<0.9.0,>=0.8.4->pygfx>=0.1.10->fastplotlib) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (3.4)
# Requirement already satisfied: pytz>=2015.7 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from babel>=2.10->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2022.6)
# Requirement already satisfied: pycparser in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from cffi>=1.15.0rc2->wgpu<0.9.0,>=0.8.4->pygfx>=0.1.10->fastplotlib) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (0.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->fastplotlib) (0.4)
# Requirement already satisfied: jupyter-events~=0.5.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (0.5.0)
# Requirement already satisfied: tinycss2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.7.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (2.0.4)
# Requirement already satisfied: bleach in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.7.1)
# Requirement already satisfied: fastjsonschema in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2.1.1)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (0.18.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (21.2.0)
# Requirement already satisfied: pure-eval in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (1.2.0)
# Requirement already satisfied: six in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=4.0.0->ipywidgets<8.0.0->fastplotlib) (1.16.0)
# Requirement already satisfied: python-json-logger in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-events~=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (2.0.4)
# Requirement already satisfied: pyyaml in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jupyter-events~=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab->fastplotlib) (6.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab->fastplotlib) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\1\appdata\roaming\python\python310\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\1\appdata\roaming\python\python310\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (2.3)
# Requirement already satisfied: rfc3986-validator>0.1.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (0.1.1)
# Requirement already satisfied: uri-template in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (1.2.0)
# Requirement already satisfied: isoduration in c:\users\1\appdata\roaming\python\python310\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (20.11.0)
# Requirement already satisfied: rfc3339-validator in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (0.1.4)
# Requirement already satisfied: webcolors>=1.11 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\1\appdata\roaming\python\python310\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab->fastplotlib) (1.2.3)
# Requirement already satisfied: PySide6 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (6.4.2)
# Requirement already satisfied: PySide6-Addons==6.4.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from PySide6) (6.4.2)
# Requirement already satisfied: shiboken6==6.4.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from PySide6) (6.4.2)
# Requirement already satisfied: PySide6-Essentials==6.4.2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from PySide6) (6.4.2)
# Requirement already satisfied: wgpu in c:\users\1\appdata\roaming\python\python310\site-packages (0.8.4)
# Requirement already satisfied: cffi>=1.15.0rc2 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from wgpu) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from cffi>=1.15.0rc2->wgpu) (2.21)
# Collecting cmasher
#   Downloading cmasher-1.6.3-py3-none-any.whl (367 kB)
#      -------------------------------------- 367.1/367.1 kB 4.6 MB/s eta 0:00:00
# Collecting colorspacious>=1.1.0
#   Downloading colorspacious-1.1.2-py2.py3-none-any.whl (37 kB)
# Collecting e13tools>=0.9.4
#   Downloading e13tools-0.9.6-py3-none-any.whl (40 kB)
#      ---------------------------------------- 40.9/40.9 kB ? eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from cmasher) (1.23.4)
# Requirement already satisfied: matplotlib>=2.2.4 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from cmasher) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from matplotlib>=2.2.4->cmasher) (4.38.0)
# Requirement already satisfied: six>=1.5 in c:\users\1\anaconda3\envs\caiman\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.4->cmasher) (1.16.0)
# Installing collected packages: colorspacious, e13tools, cmasher
# Successfully installed cmasher-1.6.3 colorspacious-1.1.2 e13tools-0.9.6

# %%
# %run main.py
# Out:
# Found 9 avi files: [WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/0.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/1.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/2.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/3.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/4.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/5.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/6.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/7.avi'), WindowsPath('F:/ROlga/Rudy_old-young-11-2022_03-2023/group1/test/M1/2023_03_16/12_16_51/Miniscope/8.avi')]
# Data shape: (8934, 600, 600)
# Found 0 avi files: []
# Data shape: (0,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:168, in ImageViewerWidget.change_time_value(self, data)
#     165 self.slider.repaint()
#     167 self.spinBox.setValue(int(data))
# --> 168 self.im.data = self.image_data[int(data),:,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:168, in ImageViewerWidget.change_time_value(self, data)
#     165 self.slider.repaint()
#     167 self.spinBox.setValue(int(data))
# --> 168 self.im.data = self.image_data[int(data),:,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:168, in ImageViewerWidget.change_time_value(self, data)
#     165 self.slider.repaint()
#     167 self.spinBox.setValue(int(data))
# --> 168 self.im.data = self.image_data[int(data),:,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:168, in ImageViewerWidget.change_time_value(self, data)
#     165 self.slider.repaint()
#     167 self.spinBox.setValue(int(data))
# --> 168 self.im.data = self.image_data[int(data),:,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:168, in ImageViewerWidget.change_time_value(self, data)
#     165 self.slider.repaint()
#     167 self.spinBox.setValue(int(data))
# --> 168 self.im.data = self.image_data[int(data),:,:]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\cadet_pipeline\CaDet-GUI\main.py:48, in GUIMainWindow.load_file(self)
#      47 def load_file(self):
# ---> 48     self.tabs.currentWidget().load()
#
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:273, in CropperCentralWidget.load(self)
#     271  self.im_viewer.load_data_from_directory(directory)
#     272 # self.im_viewer.set_image_data(np.random.rand(100,500,500))
# --> 273  self.im_viewer.setup_plot()
#     274  self.im_viewer.setup_croppers()
#     275  self.adjust_SpinBoxes_limits()
#
# File ~\cadet_pipeline\CaDet-GUI\CropperCentralWidget.py:146, in ImageViewerWidget.setup_plot(self)
#     144 def setup_plot(self):
#     145     self.plot = fastplotlib.Plot(canvas=self.canvas)
# --> 146     self.im = fastplotlib.graphics.image.ImageGraphic(self.image_data[0,:,:])
#     147     self.plot.add_graphic(self.im)
#     148     self.plot.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
# Draw error
# Traceback (most recent call last):
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\wgpu\gui\base.py", line 23, in log_exception
#     yield
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\wgpu\gui\base.py", line 172, in _draw_frame_and_present
#     self.draw_frame()
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\fastplotlib\plot.py", line 87, in render
#     super(Plot, self).render()
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\fastplotlib\layouts\_subplot.py", line 154, in render
#     super(Subplot, self).render()
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\fastplotlib\layouts\_base.py", line 118, in render
#     self.viewport.render(self.scene, self.camera)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\utils\viewport.py", line 68, in render
#     self.renderer.render(scene, camera, rect=self.rect, flush=False)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_renderer.py", line 480, in render
#     container_group = get_pipeline_container_group(
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_pipeline.py", line 42, in get_pipeline_container_group
#     pipeline_container_group.update(wobject, environment, shared, changed_labels)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_pipeline.py", line 259, in update
#     container.update(wobject, environment, shared, changed)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_pipeline.py", line 337, in update
#     raise err
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_pipeline.py", line 334, in update
#     self.update_shader_data(wobject, shared, changed)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_pipeline.py", line 365, in update_shader_data
#     update_resource(shared.device, resource, kind)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_update.py", line 33, in update_resource
#     return update_texture(device, resource)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\renderers\wgpu\_update.py", line 142, in update_texture
#     subdata = resource._get_subdata(offset, size, pixel_padding)
#   File "C:\Users\1\AppData\Roaming\Python\Python310\site-packages\pygfx\resources\_texture.py", line 228, in _get_subdata
#     sub_arr = arr[tuple(slices)]
#   File "C:\Users\1\anaconda3\envs\caiman\lib\site-packages\numpy\matrixlib\defmatrix.py", line 193, in __getitem__
#     out = N.ndarray.__getitem__(self, index)
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open("data/sample_CAIMAN_output.pickle","rb") as f:
    data = pickle.load(f)

# %%
data.YrA.shape
# Out:
# (130, 11917)

# %%
data.A.sum(axis=1).rehs
# Out:
# (237350, 1)

# %%
from skimage.measure import find_contours

# %%
plt.imshow(np.reshape(data.A.sum(axis=1), data.dims, order='F'))

# %%
component_matrix = np.reshape(data.A[:,3].toarray(), data.dims, order='F')
contour = np.array(find_contours(component_matrix>0, 0)[0])

# %%
plt.imshow(component_matrix)
for s in contour:
    plt.plot(s[:,1],s[:,0])
plt.xlim(170,200)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
contour = np.array(find_contours(component_matrix>0))[0,:,:]

# %%
np.append(np.array([1,2]),0)
# Out:
# array([1, 2, 0])

# %%
plt.imshow(component_matrix>0)
plt.plot(contour[:,1],contour[:,0])

# %%
with open("CNMF_A_and_C_sample.pickle", "wb") as f:
    pickle.dump({"A":data.A,"C":data.C,"dims":data.dims}, f)

# %%
from moviepy.editor import VideoFileClip
import numpy as np

def load_video_from_list_of_files(paths):
    # This function loads videos using moviepy
    video = []
    for path in paths:
        clip = VideoFileClip(str(path))
        for frame in clip.iter_frames():
            video.append(frame[:,:,0])
        del video[-1] # To remove last duplicated frame
    return np.asarray(video)

# %%
from glob import glob

root = 'F:\\ROlga\\Rudy_old-young-11-2022_03-2023\\Video-for-check\\M27old\\2023_03_21\\14_14_49\\Miniscope\\'
data = load_video_from_list_of_files(glob(root + '*.avi'))

# %%
data.shape
# Out:
# (5928, 600, 600)

# %%
import matplotlib.pyplot as plt
plt.plot([np.max(im) for im in data])
