# %%
import fastplotlib
import numpy as np
from wgpu.gui.auto import WgpuCanvas

# %%
canvas = WgpuCanvas()
plot = fastplotlib.Plot(canvas=canvas)
data = np.random.randn(500,500)
im = fastplotlib.graphics.ImageGraphic(data)
plot.add_graphic(im)
plot.show()
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-e738bb8e4d56416db22c05135d02303c' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:300.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# JupyterWgpuCanvas()

# %%
im_data = load_video_from_file("../data/0.avi")

# %%
import matplotlib.pyplot as plt

# %%
im_data.shape
# Out:
# (1000, 600, 600, 3)

# %%
im_data[0,:,:,0]
# Out:
# array([[ 9,  9, 11, ..., 18, 15, 16],
#        [ 6, 10, 10, ..., 16, 16, 17],
#        [ 8, 10, 11, ..., 18, 16, 15],
#        ...,
#        [ 0,  0,  0, ...,  6,  8,  5],
#        [ 1,  0,  0, ...,  4,  3,  3],
#        [ 0,  0,  1, ...,  4,  5,  5]], dtype=uint8)

# %%
im_data[0,:,:,2]
# Out:
# array([[ 9,  9, 11, ..., 18, 15, 16],
#        [ 6, 10, 10, ..., 16, 16, 17],
#        [ 8, 10, 11, ..., 18, 16, 15],
#        ...,
#        [ 0,  0,  0, ...,  6,  8,  5],
#        [ 1,  0,  0, ...,  4,  3,  3],
#        [ 0,  0,  1, ...,  4,  5,  5]], dtype=uint8)

# %%
plt.imshow(im_data[0,:,:,2])
